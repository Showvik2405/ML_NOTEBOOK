# %%
# This is a comment
print("Hello, Python!")
# Out:
# Hello, Python!

# %%
x = 5       # Integer
name = "Alice"  # String
pi = 3.14   # Float
is_valid = True  # Boolean

# %% [markdown]
# | Type    | Example                             |
# | ------- | ----------------------------------- |
# | `int`   | `x = 10`                            |
# | `float` | `pi = 3.14`                         |
# | `str`   | `name = "Bob"`                      |
# | `bool`  | `flag = True`                       |
# | `list`  | `nums = [1, 2, 3]`                  |
# | `tuple` | `coordinates = (1, 2)`              |
# | `dict`  | `info = {"name": "Mr X", "age": 28}`|

# %%
# Basic data types
a = 10               # int
b = 3.14             # float
c = "Hello"          # string
d = [1, 2, 3]        # list
e = (4, 5, 6)        # tuple
f = {"x": 1, "y": 2} # dict
g = True             # bool

print(type(d))       # Output: <class 'list'>
# Out:
# <class 'list'>

# %% [markdown]
# **I/O operations****

# %%
name = input("Enter your name: ")
print("Hello,", name)
age = int(input("Enter your age: "))  # Convert string to int
#print("You will be", age + 1, "next year.")
print(f'Hi {name}, You will be {age+1} in next year')
# Out:
# Enter your name:  mmi
# Hello, mmi
# Enter your age:  28
# Hi mmi, You will be 29 in next year

# %%
print(type(name))
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
# Ask for user details and print a message
name = input("Enter your name: ")
age = int(input("Enter your age: "))
print(f"Hi {name}, you will be {age + 1} next year.")
# Out:
# Enter your name:  M
# Enter your age:  29
# Hi M, you will be 30 next year.

# %%
print(bin(4))
print(int('0b100', 2))
print(int('0b1010', 2))
# Out:
# 0b100
# 4
# 10

# %%
year = int(input('birth year:'))
print(f'your age is {2025-year}')
# Out:
# birth year: 1980
# your age is 45

# %%
# P01: take birthyear as input and print age
birth_year = input('Birth year:')
Present_time = 2025
age = int(Present_time) - int(birth_year)
print(f'Your age is {age} years')
# Out:
# Birth year: 1997
# Your age is 28 years

# %% [markdown]
# # # P02: Take username and password as input and show thier password as * and length of password

# %%
name = input('Enter your name:')
password = input('Enter your password:')
x = len(password)
print('*'* x)
y= '*'* x
print(f'Hi {name}, your password {y} is correct')
# Out:
# Enter your name: mmi
# Enter your password: 12345
# *****
# Hi mmi, your password ***** is correct

# %%
user_name = input('Enter your name:')
password = input('Enter your password:')
pass_length = len(password)
# #hidden_pass = password[0] + '*' * (pass_length-1) + password[pass_length]
password_new = password[0] + '*' * (pass_length - 2) + password[-1]
print(f'Hello, {user_name}, Your password {password_new} is of {pass_length} digit long')
# Out:
# Enter your name: mmi
# Enter your password: 123456789
# Hello, mmi, Your password 1*******9 is of 9 digit long

# %%
print(password[len(password)-1])
# Out:
# 9

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
print('*'* 5)
# Out:
# *****

# %%
x = str(1234567)
print(x[7])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_35/1452018562.py in <cell line: 0>()
#       1 x = str(1234567)
# ----> 2 print(x[7])
#
# IndexError: string index out of range
